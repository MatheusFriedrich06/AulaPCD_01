# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusFriedrich06/AulaPCD_01/blob/main/AtividadeAula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = 50
B = 70
C = 90

valorMedia = (A + B + C) / 3
print(f"As notas são: {A}, {B}, {C}")
print(f"A média das notas ficaria: {valorMedia}")
# Out:
# As notas são: 50, 70, 90
# A média das notas ficaria: 70.0
